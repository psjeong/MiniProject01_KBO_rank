# %%
import pymysql
pymysql.install_as_MySQLdb()
import pandas as pd
from pandas import DataFrame
import sqlalchemy

#mysql 접속정보
user_name = 'proj_user'
password = '1234'
db_name = 'mini_project_1'

#csv 파일 불러오기
df = pd.read_csv("pitcher.csv")

#to_sql을 이용한 입력
connection = sqlalchemy.create_engine("mysql+mysqldb://{}:{}@localhost/{}?charset=utf8".format(user_name, password, db_name), encoding='utf-8')
table_name = 'KBO_pitcher_data'
df.to_sql(name=table_name, con=connection, if_exists = 'replace', index=True)

db.close()
df
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Input In [21], in <cell line: 18>()
#      16 connection = sqlalchemy.create_engine("mysql+mysqldb://{}:{}@localhost/{}?charset=utf8".format(user_name, password, db_name), encoding='utf-8')
#      17 table_name = 'KBO_pitcher_data'
# ---> 18 df.to_sql(name=table_name, con=connection, if_exists = 'replace', index=True)
#      20 db.close()
#      21 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
# ...
